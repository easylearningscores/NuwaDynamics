# %%
import os
import os.path as osp
import json
from typing import Any
import torch
import pickle
import logging
import numpy as np
from model import Fourier_Model
from tqdm import tqdm
from API import dataloader
from utils import *
from timeit import default_timer
import torch
import os
import os.path as osp
import numpy as np
import torch
import torch.nn as nn
import numpy as np
import random
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
import io

# %%
class Tester:
    def __init__(self, model, test_loader, path):
        self.model = model
        self.test_loader = test_loader
        self.path = path
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    def load_checkpoint(self, checkpoint_path):
        with open(checkpoint_path, 'rb') as f:
            buffer = io.BytesIO(f.read())
        
        checkpoint = torch.load(buffer)
        self.model.load_state_dict(checkpoint)
        self.model.to(self.device)

    def test(self, checkpoint_path):
        self.load_checkpoint(checkpoint_path) 
        self.model.eval()
        inputs_lst, trues_lst, preds_lst = [], [], []
        for batch_x, batch_y in self.test_loader:
            pred_y, x_rec = self.model(batch_x.to(self.device))


            list(map(lambda data, lst: lst.append(data.detach().cpu().numpy()), [
                 batch_x, batch_y, pred_y], [inputs_lst, trues_lst, preds_lst]))
        inputs, trues, preds = map(lambda data: np.concatenate(
            data, axis=0), [inputs_lst, trues_lst, preds_lst])

        folder_path = self.path+'/results/{}/sv/'
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        # 计算RMSE
        rmse = torch.sqrt(torch.mean((torch.tensor(preds) - torch.tensor(trues)) ** 2))
        rmse = rmse.item()
        
        for np_data in ['inputs', 'trues', 'preds']:
            np.save(osp.join(folder_path, np_data + '.npy'), vars()[np_data])
        return rmse

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

class TaxiBJDataset(torch.utils.data.Dataset):
    def __init__(self, input_data, output_data):
        self.input_data = input_data
        self.output_data = output_data
        self.mean = np.mean(input_data)
        self.std = np.std(input_data)
        
    def __len__(self):
        return len(self.input_data)
    
    def __getitem__(self, idx):
        input_sample = self.input_data[idx]
        output_sample = self.output_data[idx]
        
        # normalize the input and output samples
        #input_sample = (input_sample - self.mean) / self.std
        #output_sample = (output_sample - self.mean) / self.std
        
        input_sample = torch.from_numpy(input_sample).to(torch.float32)
        output_sample = torch.from_numpy(output_sample).to(torch.float32)
        return input_sample[:,:,::4,::4], output_sample
    

def load_data(batch_size, val_batch_size, data_root, num_workers):

    train_input_data = np.load(data_root + 'TaxiBJ/train_input_data_reshaped.npy')
    train_output_data = np.load(data_root + 'TaxiBJ/train_output_data_reshaped.npy')
    # train_input_data = train_input_data.reshape(3555, 12, 2, 128, 128)
    # train_output_data = train_output_data.reshape(3555, 12, 2, 128, 128)


    test_input_data = np.load(data_root + 'TaxiBJ/test_input_data_reshaped.npy')
    test_output_data = np.load(data_root + 'TaxiBJ/test_output_data_reshaped.npy')
    # test_input_data = test_input_data.reshape(445, 12, 2, 128, 128)
    # test_output_data = test_output_data.reshape(445, 12, 2, 128, 128)
    

    val_input_data = np.load(data_root+'TaxiBJ/val_input_data_reshaped.npy')
    val_output_data = np.load(data_root+'TaxiBJ/val_output_data_reshaped.npy')
    # val_input_data = val_input_data.reshape(444, 12, 2, 128, 128)
    # val_output_data = val_output_data.reshape(444, 12, 2, 128, 128)

    train_set = TaxiBJDataset(train_input_data, train_output_data)
    test_set = TaxiBJDataset(test_input_data, test_output_data)
    val_set = TaxiBJDataset(val_input_data, val_output_data)

    dataloader_train = DataLoader(train_set, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=num_workers)
    dataloader_test = DataLoader(test_set, batch_size=val_batch_size, shuffle=False, pin_memory=True, num_workers=num_workers)
    dataloader_validation = DataLoader(val_set, batch_size=val_batch_size, shuffle=False, pin_memory=True, num_workers=num_workers)

    mean, std = 0, 1

    return dataloader_train, dataloader_validation, dataloader_test, mean, std

# %%
dataloader_train, dataloader_validation, dataloader_test, mean, std = load_data(batch_size=1, 
                                                                                    val_batch_size=1, 
                                                                                    data_root='/data/workspace/yancheng/MM/earthfarseer/data/',
                                                                                    num_workers=8)

# %%
model = Fourier_Model(shape_in = [12, 2, 128, 128], hid_S=64, hid_T=256, N_S=2, N_T=4, groups=2)

test_loader = dataloader_test

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

path = '/data/workspace/yancheng/MM/earthfarseer/results_super_res'

tester = Tester(model=model, test_loader=test_loader, path=path)
args = argparse.Namespace(checkpoint_path='/data/workspace/yancheng/MM/earthfarseer/results_super_res/results_super_res/checkpoint.pth')
mse = tester.test(args.checkpoint_path)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-c20f722f672f> in <module>
#       9 tester = Tester(model=model, test_loader=test_loader, path=path)
#      10 args = argparse.Namespace(checkpoint_path='/data/workspace/yancheng/MM/earthfarseer/results_super_res/results_super_res/checkpoint.pth')
# ---> 11 mse = tester.test(args.checkpoint_path)
#      12 print(mse)
#
# <ipython-input-3-d70fb3997aec> in test(self, checkpoint_path)
#      15
#      16     def test(self, checkpoint_path):
# ---> 17         self.load_checkpoint(checkpoint_path) # 加载预训练好的模型参数
#      18         self.model.eval()
#      19         inputs_lst, trues_lst, preds_lst = [], [], []
#
# <ipython-input-3-d70fb3997aec> in load_checkpoint(self, checkpoint_path)
#      11
#      12         checkpoint = torch.load(buffer)
# ---> 13         self.model.load_state_dict(checkpoint)
#      14         self.model.to(self.device)
#      15
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    2039
#    2040         if len(error_msgs) > 0:
# -> 2041             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2042                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    2043         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Fourier_Model:
# 	size mismatch for hid.enc.0.conv1.weight: copying a param with shape torch.Size([64, 768, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 768, 1, 1]).
# 	size mismatch for hid.enc.0.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.enc.0.layers.0.conv.weight: copying a param with shape torch.Size([128, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 3, 3]).
# 	size mismatch for hid.enc.0.layers.0.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.0.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.0.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.1.conv.weight: copying a param with shape torch.Size([128, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([256, 64, 5, 5]).
# 	size mismatch for hid.enc.0.layers.1.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.1.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.1.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.2.conv.weight: copying a param with shape torch.Size([128, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 64, 7, 7]).
# 	size mismatch for hid.enc.0.layers.2.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.2.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.2.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.3.conv.weight: copying a param with shape torch.Size([128, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([256, 64, 11, 11]).
# 	size mismatch for hid.enc.0.layers.3.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.3.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.0.layers.3.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.conv1.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 256, 1, 1]).
# 	size mismatch for hid.enc.1.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.enc.1.layers.0.conv.weight: copying a param with shape torch.Size([128, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 3, 3]).
# 	size mismatch for hid.enc.1.layers.0.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.0.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.0.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.1.conv.weight: copying a param with shape torch.Size([128, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([256, 64, 5, 5]).
# 	size mismatch for hid.enc.1.layers.1.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.1.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.1.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.2.conv.weight: copying a param with shape torch.Size([128, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 64, 7, 7]).
# 	size mismatch for hid.enc.1.layers.2.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.2.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.2.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.3.conv.weight: copying a param with shape torch.Size([128, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([256, 64, 11, 11]).
# 	size mismatch for hid.enc.1.layers.3.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.3.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.1.layers.3.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.conv1.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 256, 1, 1]).
# 	size mismatch for hid.enc.2.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.enc.2.layers.0.conv.weight: copying a param with shape torch.Size([128, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 3, 3]).
# 	size mismatch for hid.enc.2.layers.0.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.0.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.0.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.1.conv.weight: copying a param with shape torch.Size([128, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([256, 64, 5, 5]).
# 	size mismatch for hid.enc.2.layers.1.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.1.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.1.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.2.conv.weight: copying a param with shape torch.Size([128, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 64, 7, 7]).
# 	size mismatch for hid.enc.2.layers.2.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.2.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.2.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.3.conv.weight: copying a param with shape torch.Size([128, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([256, 64, 11, 11]).
# 	size mismatch for hid.enc.2.layers.3.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.3.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.2.layers.3.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.conv1.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 256, 1, 1]).
# 	size mismatch for hid.enc.3.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.enc.3.layers.0.conv.weight: copying a param with shape torch.Size([128, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 3, 3]).
# 	size mismatch for hid.enc.3.layers.0.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.0.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.0.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.1.conv.weight: copying a param with shape torch.Size([128, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([256, 64, 5, 5]).
# 	size mismatch for hid.enc.3.layers.1.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.1.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.1.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.2.conv.weight: copying a param with shape torch.Size([128, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 64, 7, 7]).
# 	size mismatch for hid.enc.3.layers.2.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.2.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.2.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.3.conv.weight: copying a param with shape torch.Size([128, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([256, 64, 11, 11]).
# 	size mismatch for hid.enc.3.layers.3.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.3.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.enc.3.layers.3.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.conv1.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 256, 1, 1]).
# 	size mismatch for hid.dec.0.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.dec.0.layers.0.conv.weight: copying a param with shape torch.Size([128, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 3, 3]).
# 	size mismatch for hid.dec.0.layers.0.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.0.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.0.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.1.conv.weight: copying a param with shape torch.Size([128, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([256, 64, 5, 5]).
# 	size mismatch for hid.dec.0.layers.1.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.1.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.1.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.2.conv.weight: copying a param with shape torch.Size([128, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 64, 7, 7]).
# 	size mismatch for hid.dec.0.layers.2.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.2.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.2.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.3.conv.weight: copying a param with shape torch.Size([128, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([256, 64, 11, 11]).
# 	size mismatch for hid.dec.0.layers.3.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.3.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.0.layers.3.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.conv1.weight: copying a param with shape torch.Size([64, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 512, 1, 1]).
# 	size mismatch for hid.dec.1.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.dec.1.layers.0.conv.weight: copying a param with shape torch.Size([128, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 3, 3]).
# 	size mismatch for hid.dec.1.layers.0.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.0.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.0.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.1.conv.weight: copying a param with shape torch.Size([128, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([256, 64, 5, 5]).
# 	size mismatch for hid.dec.1.layers.1.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.1.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.1.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.2.conv.weight: copying a param with shape torch.Size([128, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 64, 7, 7]).
# 	size mismatch for hid.dec.1.layers.2.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.2.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.2.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.3.conv.weight: copying a param with shape torch.Size([128, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([256, 64, 11, 11]).
# 	size mismatch for hid.dec.1.layers.3.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.3.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.1.layers.3.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.conv1.weight: copying a param with shape torch.Size([64, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 512, 1, 1]).
# 	size mismatch for hid.dec.2.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.dec.2.layers.0.conv.weight: copying a param with shape torch.Size([128, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 3, 3]).
# 	size mismatch for hid.dec.2.layers.0.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.0.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.0.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.1.conv.weight: copying a param with shape torch.Size([128, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([256, 64, 5, 5]).
# 	size mismatch for hid.dec.2.layers.1.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.1.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.1.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.2.conv.weight: copying a param with shape torch.Size([128, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 64, 7, 7]).
# 	size mismatch for hid.dec.2.layers.2.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.2.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.2.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.3.conv.weight: copying a param with shape torch.Size([128, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([256, 64, 11, 11]).
# 	size mismatch for hid.dec.2.layers.3.conv.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.3.norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.2.layers.3.norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for hid.dec.3.conv1.weight: copying a param with shape torch.Size([64, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 512, 1, 1]).
# 	size mismatch for hid.dec.3.conv1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for hid.dec.3.layers.0.conv.weight: copying a param with shape torch.Size([768, 8, 3, 3]) from checkpoint, the shape in current model is torch.Size([768, 64, 3, 3]).
# 	size mismatch for hid.dec.3.layers.1.conv.weight: copying a param with shape torch.Size([768, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([768, 64, 5, 5]).
# 	size mismatch for hid.dec.3.layers.2.conv.weight: copying a param with shape torch.Size([768, 8, 7, 7]) from checkpoint, the shape in current model is torch.Size([768, 64, 7, 7]).
# 	size mismatch for hid.dec.3.layers.3.conv.weight: copying a param with shape torch.Size([768, 8, 11, 11]) from checkpoint, the shape in current model is torch.Size([768, 64, 11, 11]).

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ba39e77e893> in <module>
# ----> 1 mse
#
# NameError: name 'mse' is not defined
